# %% [markdown]
# # Project : Visitors to Asean Countries Database

# %% [markdown]
# Analyzed and Prepared by : Mr. Phoung Bophakimhong, Junior Data Analyst

# %% [markdown]
# ## Table of Contents:

# %% [markdown]
#     I. Introduction
#     II. Data Gathering
#     III. Data Cleaning
#     VI. Exploratory Data Analysis
#     V. Conclusions

# %% [markdown]
# ## I. Introduction

# %% [markdown]
#     In this project, I am going to analyze the Visitors to Asean Countries Database in duration from 2015-2020 using Python modules including pandas,numpy and matplotlib as visualization . The dataset has been downloaded from website kaggle.com .
#     Questions: 1) In which year are there most visitors coming to Asean Countries? During the Peak year and Low year, which asean countries have most vistors?
#                2) Show total numbers of visitors coming to each countries in Asean , and which are the top 5 countries having most visitors?
#                3) Show average numbers of visitors coming to each countries in Asean per year
#                4) Which are the top 10 countries in the World having most visitors coming to Asean countries?
#                5) Which are the top 10 countries in the World having most visitors coming to Cambodia?

# %% [markdown]
# ## II. Data Gathering

# %%
# import package
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Upload dataset
df_original = pd.read_csv("C:\\Users\\Admin\\Desktop\\Data Analyst\\Portfolios\\Analysis on Vistors to Asean\\visitor_asean.csv")
df_original
# Out:
#     Destination Country             Origin Country      2015      2016  \
# 0     Brunei Darussalam          Total Intra-ASEAN  118719.0  117525.0
# 1     Brunei Darussalam      Total Country (World)  218213.0  218809.0
# 2     Brunei Darussalam                Total EU-27    7750.0    6941.0
# 3     Brunei Darussalam                Total EU-28   18879.0   17301.0
# 4     Brunei Darussalam             Australia [AU]    9972.0    7989.0
# ..                  ...                        ...       ...       ...
# 902            Viet Nam                Turkey [TR]       NaN       NaN
# 903            Viet Nam  United Arab Emirates [AE]       NaN       NaN
# 904            Viet Nam        United Kingdom [GB]  212798.0  254841.0
# 905            Viet Nam         United States [US]  368190.0  552644.0
# 906            Viet Nam             Venezuela [VE]       NaN       NaN
#
#          2017      2018      2019      2020
# 0    131351.0  134596.0  168705.0   32571.0
# ...

# %%
df_original.head(100)
# Out:
#    Destination Country                 Origin Country      2015      2016  \
# 0    Brunei Darussalam              Total Intra-ASEAN  118719.0  117525.0
# 1    Brunei Darussalam          Total Country (World)  218213.0  218809.0
# 2    Brunei Darussalam                    Total EU-27    7750.0    6941.0
# 3    Brunei Darussalam                    Total EU-28   18879.0   17301.0
# 4    Brunei Darussalam                 Australia [AU]    9972.0    7989.0
# ..                 ...                            ...       ...       ...
# 95            Cambodia  Islamic Republic of Iran [IR]     525.0     600.0
# 96            Cambodia                    Israel [IL]    9557.0   11180.0
# 97            Cambodia                     Italy [IT]   32177.0   35794.0
# 98            Cambodia                   Jamaica [JM]     143.0     108.0
# 99            Cambodia                     Japan [JP]  193330.0  191577.0
#
#         2017      2018      2019     2020
# ...

# %%
df_original.tail(100)
# Out:
#     Destination Country             Origin Country      2015      2016  \
# 807            Thailand               Austria [AT]   97806.0   97989.0
# 808            Thailand            Bangladesh [BD]  107394.0  103616.0
# 809            Thailand               Belgium [BE]  106100.0  112140.0
# 810            Thailand                Brazil [BR]   48522.0   63139.0
# 811            Thailand     Brunei Darussalam [BN]   13833.0   17994.0
# ..                  ...                        ...       ...       ...
# 902            Viet Nam                Turkey [TR]       NaN       NaN
# 903            Viet Nam  United Arab Emirates [AE]       NaN       NaN
# 904            Viet Nam        United Kingdom [GB]  212798.0  254841.0
# 905            Viet Nam         United States [US]  368190.0  552644.0
# 906            Viet Nam             Venezuela [VE]       NaN       NaN
#
#          2017      2018      2019      2020
# 807  104784.0  116656.0  111428.0   35524.0
# ...

# %%
df_original.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 907 entries, 0 to 906
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Destination Country  907 non-null    object
#  1   Origin Country       907 non-null    object
#  2   2015                 697 non-null    float64
#  3   2016                 524 non-null    float64
#  4   2017                 852 non-null    float64
#  5   2018                 822 non-null    float64
#  6   2019                 810 non-null    float64
#  7   2020                 832 non-null    float64
# dtypes: float64(6), object(2)
# memory usage: 56.8+ KB

# %%
# List of destination countries (Asean Countries)
asean_country = sorted(set(df_original['Destination Country']))
print(asean_country)
len(asean_country)
# Out:
# ['Brunei Darussalam', 'Cambodia', 'Indonesia', 'Lao PDR', 'Malaysia', 'Myanmar', 'Philippines', 'Singapore', 'Thailand', 'Viet Nam']
# 10

# %%
# List of origin countries
list_org_country = sorted(set(df_original['Origin Country']))
print(list_org_country)
len(list_org_country)
# Out:
# ['ASEAN not specified [A]', 'Afghanistan [AF]', 'Albania [AL]', 'Algeria [DZ]', 'American Samoa [AS]', 'Andorra [AD]', 'Angola [AO]', 'Antigua and Barbuda [AG]', 'Argentina [AR]', 'Armenia [AM]', 'Aruba [AW]', 'Australia [AU]', 'Austria [AT]', 'Azerbaijan [AZ]', 'Bahrain [BH]', 'Bangladesh [BD]', 'Belarus [BY]', 'Belgium [BE]', 'Belize [BZ]', 'Benin [BJ]', 'Bhutan [BT]', 'Bolivia [BO]', 'Bosnia and Herzegovina [BA]', 'Botswana [BW]', 'Brazil [BR]', 'Brunei Darussalam [BN]', 'Bulgaria [BG]', 'Burkina Faso [BF]', 'Burundi [BI]', 'Cabo Verde [CV]', 'Cambodia [KH]', 'Cameroon [CM]', 'Canada [CA]', 'Central African Republic [CF]', 'Chad [TD]', 'Chile [CL]', 'China [CN]', 'Colombia [CO]', 'Comoros [KM]', 'Cook Islands [CK]', 'Costa Rica [CR]', 'Croatia [HR]', 'Cuba [CU]', 'Cyprus [CY]', 'Czech Republic [CZ]', "Côte d'Ivoire [CI]", "Democratic People's Republic of Korea [KP]", 'Democratic Republic of the Congo [CD]', 'Denmark [DK]', 'Djibouti [DJ]', 'Dominica [DM]', 'Dominican Republic [DO]
# ...

# %%
# We create another database which excludes  'ASEAN not specified [A]','Others Unspecified Countries [O0]','Total Country (World)', 'Total EU-27', 'Total EU-28', 'Total Intra-ASEAN'
# The reason is that above elements have combined numbers of visitors from various countries, which make some controversy on Data analysis.
unwanted_list = ['ASEAN not specified [A]','Others Unspecified Countries [O0]','Total Country (World)', 'Total EU-27', 'Total EU-28', 'Total Intra-ASEAN']
df = df_original[~df_original['Origin Country'].isin(unwanted_list)]
df
# Out:
#     Destination Country             Origin Country      2015      2016  \
# 4     Brunei Darussalam             Australia [AU]    9972.0    7989.0
# 5     Brunei Darussalam               Austria [AT]     122.0     128.0
# 6     Brunei Darussalam               Bahrain [BH]      27.0      19.0
# 7     Brunei Darussalam            Bangladesh [BD]    1531.0    2627.0
# 8     Brunei Darussalam               Belgium [BE]     160.0     137.0
# ..                  ...                        ...       ...       ...
# 902            Viet Nam                Turkey [TR]       NaN       NaN
# 903            Viet Nam  United Arab Emirates [AE]       NaN       NaN
# 904            Viet Nam        United Kingdom [GB]  212798.0  254841.0
# 905            Viet Nam         United States [US]  368190.0  552644.0
# 906            Viet Nam             Venezuela [VE]       NaN       NaN
#
#          2017      2018      2019      2020
# 4      8600.0    9702.0   10188.0    2597.0
# ...

# %% [markdown]
# ## III. Data Cleaning

# %%
# Check if there's any duplicated value
df.duplicated().any() # False : No duplicated value
# Out:
# False

# %%
# Check how many rows which contains null value
df.isnull().sum()
# Out:
# Destination Country      0
# Origin Country           0
# 2015                   209
# 2016                   383
# 2017                    54
# 2018                    84
# 2019                    96
# 2020                    63
# dtype: int64

# %%
# Replace null values in each column 2015-2020 with median value
# Median value is suitable because there are a lot of outliers value in a column, that we should not use mean()
for x in ['2015','2016','2017','2018','2019','2020']:
    df[x].fillna(df[x].median(),inplace = True)
df
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_28472\1870626809.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[x].fillna(df[x].median(),inplace = True)
#     Destination Country             Origin Country      2015      2016  \
# 4     Brunei Darussalam             Australia [AU]    9972.0    7989.0
# 5     Brunei Darussalam               Austria [AT]     122.0     128.0
# 6     Brunei Darussalam               Bahrain [BH]      27.0      19.0
# 7     Brunei Darussalam            Bangladesh [BD]    1531.0    2627.0
# 8     Brunei Darussalam               Belgium [BE]     160.0     137.0
# ..                  ...                        ...       ...       ...
# 902            Viet Nam                Turkey [TR]    8739.0   24797.0
# ...

# %%
# Check if there's any null value left
df.isnull().any() # False : No null value
# Out:
# Destination Country    False
# Origin Country         False
# 2015                   False
# 2016                   False
# 2017                   False
# 2018                   False
# 2019                   False
# 2020                   False
# dtype: bool

# %%
# Show information about the DataFrame
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 856 entries, 4 to 906
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Destination Country  856 non-null    object
#  1   Origin Country       856 non-null    object
#  2   2015                 856 non-null    float64
#  3   2016                 856 non-null    float64
#  4   2017                 856 non-null    float64
#  5   2018                 856 non-null    float64
#  6   2019                 856 non-null    float64
#  7   2020                 856 non-null    float64
# dtypes: float64(6), object(2)
# memory usage: 60.2+ KB

# %%
print(df.to_string())
# Out:
#     Destination Country                              Origin Country        2015        2016        2017        2018        2019       2020
# 4     Brunei Darussalam                              Australia [AU]      9972.0      7989.0      8600.0      9702.0     10188.0     2597.0
# 5     Brunei Darussalam                                Austria [AT]       122.0       128.0       101.0       158.0      5873.5       18.0
# 6     Brunei Darussalam                                Bahrain [BH]        27.0        19.0       131.0        39.0      5873.5        5.0
# 7     Brunei Darussalam                             Bangladesh [BD]      1531.0      2627.0      3553.0      3878.0      3281.0      638.0
# 8     Brunei Darussalam                                Belgium [BE]       160.0       137.0       181.0       125.0      5873.5       46.0
# 9     Brunei Darussalam                               Cambodia [KH]       251.0       318.0       356.0       420.0       463.0       29.0
# ...

# %%
# Show data type of each column
df.dtypes
# Out:
# Destination Country     object
# Origin Country          object
# 2015                   float64
# 2016                   float64
# 2017                   float64
# 2018                   float64
# 2019                   float64
# 2020                   float64
# dtype: object

# %%
# Because number of column '2015','2016','2017','2018','2019','2020' show numbers of visitors, so I decide to change data type to integer.
df[['2015','2016','2017','2018','2019','2020']]= df[['2015','2016','2017','2018','2019','2020']].astype('i')
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_28472\433920363.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[['2015','2016','2017','2018','2019','2020']]= df[['2015','2016','2017','2018','2019','2020']].astype('i')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 856 entries, 4 to 906
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Destination Country  856 non-null    object
#  1   Origin Country       856 non-null    object
#  2   2015                 856 non-null    int32
#  3   2016                 856 non-null    int32
#  4   2017                 856 non-null    int32
#  5   2018                 856 non-null    int32
#  6   2019                 856 non-null    int32
#  7   2020                 856 non-null    int32
# dtypes: int32(6), object(2)
# memory usage: 40.1+ KB

# %%
# Generate descriptive statistics
df.describe()
# Out:
#                2015          2016          2017          2018          2019  \
# count  8.560000e+02  8.560000e+02  8.560000e+02  8.560000e+02  8.560000e+02
# mean   1.257068e+05  1.385209e+05  1.442635e+05  1.550265e+05  1.646365e+05
# std    6.025032e+05  6.337142e+05  6.571827e+05  6.669576e+05  6.968753e+05
# min    1.000000e+00  1.700000e+01  3.000000e+00  1.000000e+00  1.000000e+00
# 25%    1.195250e+03  1.886600e+04  4.492500e+02  4.307500e+02  4.927500e+02
# 50%    8.739000e+03  2.479700e+04  5.383000e+03  5.268000e+03  5.873000e+03
# 75%    3.206300e+04  3.228125e+04  3.958275e+04  3.906750e+04  4.218425e+04
# max    1.293075e+07  1.327296e+07  1.244171e+07  1.061599e+07  1.099717e+07
#
#                2020
# count  8.560000e+02
# mean   2.961743e+04
# std    1.129665e+05
# min    1.000000e+00
# 25%    9.800000e+01
# 50%    1.325000e+03
# 75%    8.835000e+03
# max    1.545255e+06

# %%
print(df.to_string())
# Out:
#     Destination Country                              Origin Country      2015      2016      2017      2018      2019     2020
# 4     Brunei Darussalam                              Australia [AU]      9972      7989      8600      9702     10188     2597
# 5     Brunei Darussalam                                Austria [AT]       122       128       101       158      5873       18
# 6     Brunei Darussalam                                Bahrain [BH]        27        19       131        39      5873        5
# 7     Brunei Darussalam                             Bangladesh [BD]      1531      2627      3553      3878      3281      638
# 8     Brunei Darussalam                                Belgium [BE]       160       137       181       125      5873       46
# 9     Brunei Darussalam                               Cambodia [KH]       251       318       356       420       463       29
# ...

# %% [markdown]
# ## VI. Exploratory Data Analysis

# %% [markdown]
# 1) In which year are there most visitors coming to Asean Countries? During the Peak year and Low year, which asean countries have most vistors?

# %%
# Calculate total of visitors by years
total_visitors_year = pd.Series([df['2015'].sum(),
                               df['2016'].sum(),
                               df['2017'].sum(),
                               df['2018'].sum(),
                               df['2019'].sum(),
                               df['2020'].sum()],index=['2015','2016','2017','2018','2019','2020'])
print(total_visitors_year)
# Out:
# 2015    107605028
# 2016    118573871
# 2017    123489595
# 2018    132702708
# 2019    140928859
# 2020     25352520
# dtype: int64

# %%
year = ['2015','2016','2017','2018','2019','2020']

# %%
plt.plot(year,total_visitors_year,marker = 'o',mfc = 'r')
plt.title("Total of Visitors to Asean Countries by Years")
plt.xlabel("Years")
plt.ylabel("Numbers of Visitor")
plt.show()

# %% [markdown]
# @@ Result Analysis : About line plot chart, it shows that numbers of visitors increased from above 100 millions in 2015 to 140 milllions in 2019. However, this trends fell down considerably in 2020 , just about 25 millions in 2020.

# %%
# Total of visitors to Asean countries during 2016
v_asean_2019 = pd.Series(df.groupby('Destination Country')['2019'].sum())
v_asean_2019
# Out:
# Destination Country
# Brunei Darussalam      435250
# Cambodia              6610459
# Indonesia            16118000
# Lao PDR               4753653
# Malaysia             25806674
# Myanmar               4481159
# Philippines           8089630
# Singapore            18518504
# Thailand             38497930
# Viet Nam             17617600
# Name: 2019, dtype: int32

# %%
plt.pie(v_asean_2019, labels= v_asean_2019.index,autopct='%1.1f%%')
plt.title("Numbers of Visitors to Asean Countries in 2019(Peak Time)")
plt.show()

# %% [markdown]
# @@ Result Analysis : In Above line chart showing 2019 is the Peak time when having most visitors to Asean Countries. Among those Asean countries, Thailand,Malaysia,Singapores,Vietnam, and Indonesia are favorable countries which attracts most visitors. In addition, Cambodia had 4.7% of visitors from around the world coming to visit, which was noticeable high too.

# %% [markdown]
# Numbers of visitors to each country of Asean during 2020(Low Year)

# %%
# Total of visitors to Asean countries during 2020
v_asean_2020 = pd.Series(df.groupby('Destination Country')['2020'].sum())
v_asean_2020
# Out:
# Destination Country
# Brunei Darussalam      62825
# Cambodia             1305023
# Indonesia            4058136
# Lao PDR               838094
# Malaysia             4282614
# Myanmar               940443
# Philippines          1368221
# Singapore            2620069
# Thailand             6351442
# Viet Nam             3525653
# Name: 2020, dtype: int32

# %%
plt.pie(v_asean_2020, labels= v_asean_2020.index,autopct='%1.1f%%')
plt.title("Numbers of Visitors to Asean Countries in 2020(Low Time)")
plt.show()

# %% [markdown]
# @@ Result Analysis : Although, during 2020 (Low time) the numbers of visitors to Asean countries decrease remarkably, we have seen Thailand,Malaysia,Singapores,Vietnam, and Indonesia still keep being the most favorable countries, and Vietnam surpassed Singapore in numbers of visitors.

# %% [markdown]
# 2) Show total numbers of visitors coming to each countries in Asean , and which are the top 5 countries having most visitors?

# %%
# Total of visitors to each asean country year by year , v_ec: visitors to each country in Asean
v_ec_15 = pd.Series(df.groupby('Destination Country')['2015'].sum())
v_ec_16 = pd.Series(df.groupby('Destination Country')['2016'].sum())
v_ec_17 = pd.Series(df.groupby('Destination Country')['2017'].sum())
v_ec_18 = pd.Series(df.groupby('Destination Country')['2018'].sum())
v_ec_19 = pd.Series(df.groupby('Destination Country')['2019'].sum())
v_ec_20 = pd.Series(df.groupby('Destination Country')['2020'].sum())

# %%
# v_ec is Dataset showing total numbers of visitor to each Asean country in each year
v_ec = pd.DataFrame([v_ec_15,v_ec_16,v_ec_17,v_ec_18,v_ec_19,v_ec_20])
v_ec
# Out:
# Destination Country  Brunei Darussalam  Cambodia  Indonesia  Lao PDR  \
# 2015                            232256   4765933   11163694  4646905
# 2016                            265130   4970754   14470295  4195850
# 2017                            265867   5568295   14080791  3819627
# 2018                            279291   6187557   15835573  4151782
# 2019                            435250   6610459   16118000  4753653
# 2020                             62825   1305023    4058136   838094
#
# Destination Country  Malaysia  Myanmar  Philippines  Singapore  Thailand  \
# 2015                 25592609  4558291      5098384   14953269  28756853
# 2016                 26302725  5292555      5733811   16082869  31246071
# 2017                 25818026  3620313      6410374   17012991  34205794
# 2018                 25543824  3714058      6973298   18055613  36771781
# 2019                 25806674  4481159      8089630   18518504  38497930
# ...

# %%
# Using group-bar chart to show each asean countries' visitors by year
v_ec_plot = v_ec.plot(kind= 'bar', stacked = False, title='Number of Visitors to Each Asean Country by Year',figsize =(10,5))
v_ec_plot.legend(title = 'Asean Countries',loc='center left', bbox_to_anchor=(1, 0.5))

# %% [markdown]
# @@ Result Analysis : From 2015-2020, Thailand,Malaysia,Singapores,Vietnam, and Indonesia are top 5 countries having most visitors among Asean countries, while Brunei Darussalam had the least visitors. Cambodia was top 7th having most visiors

# %% [markdown]
# 3) Show average numbers of visitors coming to each countries in Asean per year

# %%
# Average numbers of visitors per year in each country in Asean during 2015-2020
v_ec_avg = v_ec.mean().astype('i')
v_ec_avg
# Out:
# Destination Country
# Brunei Darussalam      256769
# Cambodia              4901336
# Indonesia            12621081
# Lao PDR               3734318
# Malaysia             22224412
# Myanmar               3767803
# Philippines           5612286
# Singapore            14540552
# Thailand             29304978
# Viet Nam             11145224
# dtype: int32

# %%
v_ec_avg.plot(kind='bar',xlabel='Asean Countries',ylabel='Numbers of Visitors',title='Average Numbers of Visitors per year in Each Country of Asean During 2015-2020',color='g')
# Out:
# <Axes: title={'center': 'Average Numbers of Visitors per year in Each Country of Asean During 2015-2020'}, xlabel='Asean Countries', ylabel='Numbers of Visitors'>

# %% [markdown]
# 4) Which are the top 10 countries in the World having most visitors coming to Asean countries?

# %%
# Total number of visitors from each origin countries coming to Asean Countries by year

org_15 = pd.Series(df.groupby('Origin Country')['2015'].sum())
org_16 = pd.Series(df.groupby('Origin Country')['2016'].sum())
org_17 = pd.Series(df.groupby('Origin Country')['2017'].sum())
org_18 = pd.Series(df.groupby('Origin Country')['2018'].sum())
org_19 = pd.Series(df.groupby('Origin Country')['2019'].sum())
org_20 = pd.Series(df.groupby('Origin Country')['2020'].sum())
# org is Dateset of numbers of visitors from each origin countries

org = pd.DataFrame([org_15,org_16,org_17,org_18,org_19,org_20])

# Find mean value from number of visitors in whole duration 2015-2020, and take only top 10 highest mean value

avg_org = org.mean().nlargest(10)
avg_org
# Out:
# Origin Country
# China [CN]            2.160407e+07
# Singapore [SG]        1.302304e+07
# Malaysia [MY]         6.981499e+06
# Korea [KR]            6.913449e+06
# Indonesia [ID]        6.297799e+06
# Thailand [TH]         5.811299e+06
# Japan [JP]            4.404510e+06
# Australia [AU]        3.770978e+06
# United States [US]    3.590194e+06
# India [IN]            3.512461e+06
# dtype: float64

# %%
# Rank top 10 countries by using horizontal bar chart
avg_org.sort_values().plot(kind='barh',xlabel='Numbers of Visitors',ylabel='Countries of Visitors',title='Top 10 Countries Having Most Visitors to Asean Countries')
# Out:
# <Axes: title={'center': 'Top 10 Countries Having Most Visitors to Asean Countries'}, xlabel='Numbers of Visitors', ylabel='Countries of Visitors'>

# %% [markdown]
# @@ Result Analysis: Above horizontal bar chart showed countries from Top 1 (China) to Top 10 (India) which are countries having most people visiting asean countries . We could see some countries in Asean including Singapore,Malaysia,Indonesia, and Thailand also have great numbers of people going to visit other Asean Countries.

# %% [markdown]
# 5) Which are the top 10 countries in the World having most visitors coming to Cambodia?

# %%
# From df Datafram, Select dataframe only for 'Destination Country': 'Cambodia'
v_cam = df.loc[df['Destination Country']=='Cambodia']
v_cam
# Out:
#     Destination Country    Origin Country    2015    2016    2017    2018  \
# 59             Cambodia  Afghanistan [AF]     121     158     220     276
# 60             Cambodia    Argentina [AR]    7870   13497   17626   10972
# 61             Cambodia    Australia [AU]  134748  146806  143852  127430
# 62             Cambodia      Austria [AT]   10080   11203   11400   11374
# 63             Cambodia   Bangladesh [BD]    2057    1851    2227    3206
# ..                  ...               ...     ...     ...     ...     ...
# 157            Cambodia      Uruguay [UY]    1004    1166    1816    1347
# 158            Cambodia   Uzbekistan [UZ]     735     491     572     551
# 159            Cambodia    Venezuela [VE]     723     469     744     356
# 160            Cambodia     Viet Nam [VN]  987792  959663  835355  800128
# 161            Cambodia        Yemen [YE]     452     313     610     653
#
#        2019    2020
# 59      379      50
# 60     5899    2624
# ...

# %%
# Find mean values for visitors during 2015-2020
v_cam.loc[:,'Average Visitors'] = pd.Series(v_cam.mean(axis=1,numeric_only=True).astype('i'))
v_cam
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_28472\791376060.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   v_cam.loc[:,'Average Visitors'] = pd.Series(v_cam.mean(axis=1,numeric_only=True).astype('i'))
#     Destination Country    Origin Country    2015    2016    2017    2018  \
# 59             Cambodia  Afghanistan [AF]     121     158     220     276
# 60             Cambodia    Argentina [AR]    7870   13497   17626   10972
# 61             Cambodia    Australia [AU]  134748  146806  143852  127430
# 62             Cambodia      Austria [AT]   10080   11203   11400   11374
# 63             Cambodia   Bangladesh [BD]    2057    1851    2227    3206
# ..                  ...               ...     ...     ...     ...     ...
# ...

# %%
top10_v_cam = v_cam[['Origin Country','Average Visitors']].nlargest(n=10,columns='Average Visitors')
top10_v_cam
# Out:
#           Origin Country  Average Visitors
# 72            China [CN]           1241910
# 160        Viet Nam [VN]            778990
# 149        Thailand [TH]            367101
# 106         Lao PDR [LA]            350232
# 103           Korea [KR]            285018
# 156   United States [US]            211393
# 99            Japan [JP]            174607
# 112        Malaysia [MY]            151901
# 155  United Kingdom [GB]            142545
# 83           France [FR]            140084

# %%
top10_v_cam.sort_values('Average Visitors').plot.barh('Origin Country',xlabel='Numbers of Visitors',ylabel='Countries of Visitors',title='Top 10 Countries having most visitors to Cambodia',color='r')
# Out:
# <Axes: title={'center': 'Top 10 Countries having most visitors to Cambodia'}, xlabel='Numbers of Visitors', ylabel='Countries of Visitors'>

# %% [markdown]
# @@ Result Analysis: Above horizontal bar chart showed China was the country with the most people who came to visit Cambodia among other nations following by Vietnam and Thailand .

# %% [markdown]
# ## V. Conclusions

# %% [markdown]
#     During periods of 2015-2020, there are around 100-140 millions of visitors coming to Asean region .Thailand,Malaysia,Singapore,Vietnam and Indonesia are most favorable countries for visitors from around the world. In addition, Asean countries should pay attention on top countries having most visitor to the region by keeping good environment, providing great service,developing and conserving tourist spots, and keep studying their preference of tourism as well.
